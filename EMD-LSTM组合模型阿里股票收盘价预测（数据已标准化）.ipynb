# %%
import pandas as pd
import numpy as np
from PyEMD.EMD import EMD
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# 读取数据
def load_data(filename, sheet_name):
    df = pd.read_excel(filename, sheet_name=sheet_name, parse_dates=True, index_col=0)
    return df['Close'], df.index  # 返回收盘价和索引

# 进行 EMD 分解
def perform_emd(data):
    emd = EMD()  # 创建 EMD 实例
    imfs = emd.emd(data.values)  # 使用 emd 方法，并确保传入数值数组
    return imfs

# LSTM模型
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        out, _ = self.lstm(x)
        out = self.fc(out[:, -1, :])
        return out

# 数据预处理
def preprocess_data(data, sequence_length, scaler=None):
    if scaler is None:
        scaler = MinMaxScaler(feature_range=(0, 1))
        data_scaled = scaler.fit_transform(data.reshape(-1, 1)).flatten()
    else:
        data_scaled = scaler.transform(data.reshape(-1, 1)).flatten()
    
    X, y = [], []
    for i in range(len(data_scaled) - sequence_length):
        X.append(data_scaled[i:i + sequence_length])
        y.append(data_scaled[i + sequence_length])
    return np.array(X), np.array(y), scaler

# 训练函数
def train_model(model, train_loader, criterion, optimizer, num_epochs):
    model.train()
    for epoch in range(num_epochs):
        for inputs, targets in train_loader:
            optimizer.zero_grad()
            outputs = model(inputs.unsqueeze(2))  # 增加一个维度
            loss = criterion(outputs.squeeze(), targets)
            loss.backward()
            optimizer.step()
        print(f'Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}')

# 评估函数
def evaluate_model(model, data_loader, scaler):
    model.eval()
    predictions = []
    targets = []
    with torch.no_grad():
        for inputs, t in data_loader:
            outputs = model(inputs.unsqueeze(2))  # 增加一个维度
            predictions.append(scaler.inverse_transform(outputs.numpy().reshape(-1, 1)).flatten())
            targets.append(scaler.inverse_transform(t.numpy().reshape(-1, 1)).flatten())
    predictions = np.concatenate(predictions)
    targets = np.concatenate(targets)
    return predictions, targets

# 可视化结果
def plot_results(targets_train, predictions_train, targets_test, predictions_test, imf_index, index):
    plt.figure(figsize=(12, 6))
    plt.plot(index[:len(targets_train)], targets_train, label='Actual Train', linestyle='--', color='blue')
    plt.plot(index[:len(predictions_train)], predictions_train, label='Predicted Train', color='red')
    plt.plot(index[len(targets_train):len(targets_train) + len(targets_test)], targets_test, label='Actual Test', linestyle='--', color='green')
    plt.plot(index[len(predictions_train):len(predictions_train) + len(predictions_test)], predictions_test, label='Predicted Test', color='orange')
    plt.title(f'IMF {imf_index + 1} Prediction')
    plt.xlabel('Date')
    plt.ylabel('Value')
    plt.xticks(rotation=45)  # 使x坐标标记旋转以便更清晰
    plt.legend()
    plt.tight_layout()  # 自动调整 subplot 参数以给标签留出空间
    plt.show()

if __name__ == "__main__":
    # 加载数据
    filename = 'stocks_data_alphavantage.xlsx'  # 数据文件路径
    sheet_name = 'Alibaba'  # 工作表名称
    close_prices, index = load_data(filename, sheet_name)

    # 进行 EMD 分解
    imfs = perform_emd(close_prices)

    # 更新IMF数量
    num_imfs = len(imfs)

    # 可视化原始数据和IMF
    plt.figure(figsize=(12, 4 * num_imfs))  # 设置图形高度为4 * num_imfs
    
    # 在同一个图形窗口中绘制所有IMF
    for i in range(num_imfs):
        plt.subplot(num_imfs, 1, i + 1)  # 更新为num_imfs行1列
        plt.plot(index[:len(imfs[i])], imfs[i], label=f'IMF {i + 1}')
        plt.title(f'IMF {i + 1}')
        plt.xlabel('Date')
        plt.ylabel('Value')
        plt.xticks(rotation=45)
        plt.legend()
        plt.tight_layout()

    # 显示图形
    plt.show()

    # LSTM建模并训练每个IMF分量
    sequence_length = 30
    input_size = 1  # 保持为1，但需要在输入时增加一个维度
    hidden_size = 50
    num_layers = 2
    output_size = 1
    num_epochs = 50
    batch_size = 16

    all_predictions_train = []
    all_predictions_test = []
    all_targets_train = []
    all_targets_test = []

    for i in range(num_imfs):
        imf = imfs[i]

        # 处理IMF数据
        X, y, scaler = preprocess_data(imf, sequence_length)

        # 划分训练集和测试集
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05, shuffle=False)

        train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(y_train, dtype=torch.float32))
        test_dataset = TensorDataset(torch.tensor(X_test, dtype=torch.float32), torch.tensor(y_test, dtype=torch.float32))

        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
        test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

        model = LSTMModel(input_size, hidden_size, num_layers, output_size)
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=0.001)

        # 训练模型
        print(f'Training model for IMF {i + 1}...')
        train_model(model, train_loader, criterion, optimizer, num_epochs)

        # 评估模型
        predictions_train, targets_train = evaluate_model(model, train_loader, scaler)
        predictions_test, targets_test = evaluate_model(model, test_loader, scaler)

        # 打印评估报告
        mse_train = mean_squared_error(targets_train, predictions_train)
        mae_train = mean_absolute_error(targets_train, predictions_train)
        r2_train = r2_score(targets_train, predictions_train)
        print(f'IMF {i + 1} Train - MSE: {mse_train:.4f}, MAE: {mae_train:.4f}, R²: {r2_train:.4f}')

        mse_test = mean_squared_error(targets_test, predictions_test)
        mae_test = mean_absolute_error(targets_test, predictions_test)
        r2_test = r2_score(targets_test, predictions_test)
        print(f'IMF {i + 1} Test - MSE: {mse_test:.4f}, MAE: {mae_test:.4f}, R²: {r2_test:.4f}')

        # 可视化预测结果
        plot_results(targets_train, predictions_train, targets_test, predictions_test, i, index)

        # 保存预测结果
        all_predictions_train.append(predictions_train)
        all_predictions_test.append(predictions_test)
        
        all_targets_train.append(targets_train)
        all_targets_test.append(targets_test)

    # 合并所有IMF的预测结果
    combined_predictions_train = np.sum(all_predictions_train, axis=0)
    combined_predictions_test = np.sum(all_predictions_test, axis=0)
    
    combined_targets_train = np.sum(all_targets_train, axis=0)
    combined_targets_test = np.sum(all_targets_test, axis=0)

    # 评估合并后的预测结果
    mse_train_combined = mean_squared_error(combined_targets_train, combined_predictions_train)
    mae_train_combined = mean_absolute_error(combined_targets_train, combined_predictions_train)
    r2_train_combined = r2_score(combined_targets_train, combined_predictions_train)
    print(f'Combined IMF Train - MSE: {mse_train_combined:.4f}, MAE: {mae_train_combined:.4f}, R²: {r2_train_combined:.4f}')

    mse_test_combined = mean_squared_error(combined_targets_test, combined_predictions_test)
    mae_test_combined = mean_absolute_error(combined_targets_test, combined_predictions_test)
    r2_test_combined = r2_score(combined_targets_test, combined_predictions_test)
    print(f'Combined IMF Test - MSE: {mse_test_combined:.4f}, MAE: {mae_test_combined:.4f}, R²: {r2_test_combined:.4f}')

    # 可视化合并后的预测结果
    plot_results(combined_targets_train, combined_predictions_train, combined_targets_test, combined_predictions_test, -1, index)
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_44388\3103586304.py:115: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# Training model for IMF 1...
# Epoch [1/50], Loss: 0.0011
# Epoch [2/50], Loss: 0.0013
# Epoch [3/50], Loss: 0.0013
# Epoch [4/50], Loss: 0.0014
# Epoch [5/50], Loss: 0.0014
# Epoch [6/50], Loss: 0.0014
# Epoch [7/50], Loss: 0.0016
# Epoch [8/50], Loss: 0.0019
# Epoch [9/50], Loss: 0.0023
# Epoch [10/50], Loss: 0.0029
# Epoch [11/50], Loss: 0.0032
# Epoch [12/50], Loss: 0.0033
# Epoch [13/50], Loss: 0.0035
# Epoch [14/50], Loss: 0.0037
# Epoch [15/50], Loss: 0.0039
# Epoch [16/50], Loss: 0.0040
# Epoch [17/50], Loss: 0.0041
# Epoch [18/50], Loss: 0.0042
# Epoch [19/50], Loss: 0.0043
# Epoch [20/50], Loss: 0.0043
# Epoch [21/50], Loss: 0.0044
# Epoch [22/50], Loss: 0.0044
# Epoch [23/50], Loss: 0.0045
# Epoch [24/50], Loss: 0.0045
# Epoch [25/50], Loss: 0.0046
# Epoch [26/50], Loss: 0.0046
# Epoch [27/50], Loss: 0.0047
# Epoch [28/50], Loss: 0.0047
# Epoch [29/50], Loss: 0.0047
# Epoch [30/50], Loss: 0.0047
# Epoch [31/50], Loss: 0.0048
# Epoch [32/50], Loss: 0.0048
# Epoch [33/50], Loss: 0.0048
# Epoch [34/50], Loss: 0.0048
# Epoch [35/50], Loss: 0.0049
# Epoch [36/50], Loss: 0.0049
# Epoch [37/50], Loss: 0.0049
# Epoch [38/50], Loss: 0.0049
# Epoch [39/50], Loss: 0.0050
# Epoch [40/50], Loss: 0.0050
# Epoch [41/50], Loss: 0.0050
# Epoch [42/50], Loss: 0.0050
# Epoch [43/50], Loss: 0.0050
# Epoch [44/50], Loss: 0.0050
# Epoch [45/50], Loss: 0.0050
# Epoch [46/50], Loss: 0.0050
# Epoch [47/50], Loss: 0.0050
# Epoch [48/50], Loss: 0.0050
# Epoch [49/50], Loss: 0.0050
# Epoch [50/50], Loss: 0.0050
# IMF 1 Train - MSE: 3.6484, MAE: 1.4179, R²: 0.0874
# IMF 1 Test - MSE: 1.2845, MAE: 0.8417, R²: 0.0275
# Training model for IMF 2...
# Epoch [1/50], Loss: 0.0001
# Epoch [2/50], Loss: 0.0002
# Epoch [3/50], Loss: 0.0002
# Epoch [4/50], Loss: 0.0005
# Epoch [5/50], Loss: 0.0000
# Epoch [6/50], Loss: 0.0000
# Epoch [7/50], Loss: 0.0000
# Epoch [8/50], Loss: 0.0000
# Epoch [9/50], Loss: 0.0000
# Epoch [10/50], Loss: 0.0000
# Epoch [11/50], Loss: 0.0000
# Epoch [12/50], Loss: 0.0000
# Epoch [13/50], Loss: 0.0000
# Epoch [14/50], Loss: 0.0000
# Epoch [15/50], Loss: 0.0000
# Epoch [16/50], Loss: 0.0000
# Epoch [17/50], Loss: 0.0000
# Epoch [18/50], Loss: 0.0000
# Epoch [19/50], Loss: 0.0000
# Epoch [20/50], Loss: 0.0000
# Epoch [21/50], Loss: 0.0000
# Epoch [22/50], Loss: 0.0000
# Epoch [23/50], Loss: 0.0000
# Epoch [24/50], Loss: 0.0000
# Epoch [25/50], Loss: 0.0000
# Epoch [26/50], Loss: 0.0000
# Epoch [27/50], Loss: 0.0000
# Epoch [28/50], Loss: 0.0000
# Epoch [29/50], Loss: 0.0000
# Epoch [30/50], Loss: 0.0000
# Epoch [31/50], Loss: 0.0000
# Epoch [32/50], Loss: 0.0000
# Epoch [33/50], Loss: 0.0000
# Epoch [34/50], Loss: 0.0000
# Epoch [35/50], Loss: 0.0000
# Epoch [36/50], Loss: 0.0000
# Epoch [37/50], Loss: 0.0000
# Epoch [38/50], Loss: 0.0000
# Epoch [39/50], Loss: 0.0000
# Epoch [40/50], Loss: 0.0000
# Epoch [41/50], Loss: 0.0000
# Epoch [42/50], Loss: 0.0000
# Epoch [43/50], Loss: 0.0000
# Epoch [44/50], Loss: 0.0000
# Epoch [45/50], Loss: 0.0000
# Epoch [46/50], Loss: 0.0000
# Epoch [47/50], Loss: 0.0000
# Epoch [48/50], Loss: 0.0000
# Epoch [49/50], Loss: 0.0000
# Epoch [50/50], Loss: 0.0000
# IMF 2 Train - MSE: 0.3877, MAE: 0.4401, R²: 0.9368
# IMF 2 Test - MSE: 0.0919, MAE: 0.2491, R²: 0.9186
# Training model for IMF 3...
# Epoch [1/50], Loss: 0.0000
# Epoch [2/50], Loss: 0.0007
# Epoch [3/50], Loss: 0.0003
# Epoch [4/50], Loss: 0.0000
# Epoch [5/50], Loss: 0.0001
# Epoch [6/50], Loss: 0.0002
# Epoch [7/50], Loss: 0.0004
# Epoch [8/50], Loss: 0.0003
# Epoch [9/50], Loss: 0.0000
# Epoch [10/50], Loss: 0.0000
# Epoch [11/50], Loss: 0.0000
# Epoch [12/50], Loss: 0.0000
# Epoch [13/50], Loss: 0.0000
# Epoch [14/50], Loss: 0.0000
# Epoch [15/50], Loss: 0.0000
# Epoch [16/50], Loss: 0.0000
# Epoch [17/50], Loss: 0.0000
# Epoch [18/50], Loss: 0.0001
# Epoch [19/50], Loss: 0.0000
# Epoch [20/50], Loss: 0.0000
# Epoch [21/50], Loss: 0.0000
# Epoch [22/50], Loss: 0.0000
# Epoch [23/50], Loss: 0.0000
# Epoch [24/50], Loss: 0.0000
# Epoch [25/50], Loss: 0.0000
# Epoch [26/50], Loss: 0.0000
# Epoch [27/50], Loss: 0.0000
# Epoch [28/50], Loss: 0.0000
# Epoch [29/50], Loss: 0.0000
# Epoch [30/50], Loss: 0.0000
# Epoch [31/50], Loss: 0.0000
# Epoch [32/50], Loss: 0.0000
# Epoch [33/50], Loss: 0.0000
# Epoch [34/50], Loss: 0.0000
# Epoch [35/50], Loss: 0.0000
# Epoch [36/50], Loss: 0.0000
# Epoch [37/50], Loss: 0.0000
# Epoch [38/50], Loss: 0.0000
# Epoch [39/50], Loss: 0.0000
# Epoch [40/50], Loss: 0.0000
# Epoch [41/50], Loss: 0.0000
# Epoch [42/50], Loss: 0.0000
# Epoch [43/50], Loss: 0.0000
# Epoch [44/50], Loss: 0.0000
# Epoch [45/50], Loss: 0.0000
# Epoch [46/50], Loss: 0.0000
# Epoch [47/50], Loss: 0.0000
# Epoch [48/50], Loss: 0.0000
# Epoch [49/50], Loss: 0.0000
# Epoch [50/50], Loss: 0.0000
# IMF 3 Train - MSE: 0.0584, MAE: 0.1927, R²: 0.9950
# IMF 3 Test - MSE: 0.0277, MAE: 0.1473, R²: 0.9905
# Training model for IMF 4...
# Epoch [1/50], Loss: 0.0022
# Epoch [2/50], Loss: 0.0004
# Epoch [3/50], Loss: 0.0015
# Epoch [4/50], Loss: 0.0011
# Epoch [5/50], Loss: 0.0007
# Epoch [6/50], Loss: 0.0004
# Epoch [7/50], Loss: 0.0001
# Epoch [8/50], Loss: 0.0000
# Epoch [9/50], Loss: 0.0000
# Epoch [10/50], Loss: 0.0000
# Epoch [11/50], Loss: 0.0000
# Epoch [12/50], Loss: 0.0001
# Epoch [13/50], Loss: 0.0001
# Epoch [14/50], Loss: 0.0001
# Epoch [15/50], Loss: 0.0001
# Epoch [16/50], Loss: 0.0001
# Epoch [17/50], Loss: 0.0000
# Epoch [18/50], Loss: 0.0000
# Epoch [19/50], Loss: 0.0000
# Epoch [20/50], Loss: 0.0000
# Epoch [21/50], Loss: 0.0000
# Epoch [22/50], Loss: 0.0000
# Epoch [23/50], Loss: 0.0000
# Epoch [24/50], Loss: 0.0000
# Epoch [25/50], Loss: 0.0000
# Epoch [26/50], Loss: 0.0000
# Epoch [27/50], Loss: 0.0000
# Epoch [28/50], Loss: 0.0000
# Epoch [29/50], Loss: 0.0000
# Epoch [30/50], Loss: 0.0000
# Epoch [31/50], Loss: 0.0000
# Epoch [32/50], Loss: 0.0000
# Epoch [33/50], Loss: 0.0000
# Epoch [34/50], Loss: 0.0000
# Epoch [35/50], Loss: 0.0000
# Epoch [36/50], Loss: 0.0000
# Epoch [37/50], Loss: 0.0000
# Epoch [38/50], Loss: 0.0000
# Epoch [39/50], Loss: 0.0000
# Epoch [40/50], Loss: 0.0000
# Epoch [41/50], Loss: 0.0000
# Epoch [42/50], Loss: 0.0000
# Epoch [43/50], Loss: 0.0000
# Epoch [44/50], Loss: 0.0000
# Epoch [45/50], Loss: 0.0000
# Epoch [46/50], Loss: 0.0000
# Epoch [47/50], Loss: 0.0000
# Epoch [48/50], Loss: 0.0000
# Epoch [49/50], Loss: 0.0000
# Epoch [50/50], Loss: 0.0000
# IMF 4 Train - MSE: 0.0988, MAE: 0.2396, R²: 0.9964
# IMF 4 Test - MSE: 0.0379, MAE: 0.1574, R²: 0.9949
# Training model for IMF 5...
# Epoch [1/50], Loss: 0.0006
# Epoch [2/50], Loss: 0.0008
# Epoch [3/50], Loss: 0.0000
# Epoch [4/50], Loss: 0.0000
# Epoch [5/50], Loss: 0.0001
# Epoch [6/50], Loss: 0.0004
# Epoch [7/50], Loss: 0.0002
# Epoch [8/50], Loss: 0.0001
# Epoch [9/50], Loss: 0.0000
# Epoch [10/50], Loss: 0.0000
# Epoch [11/50], Loss: 0.0000
# Epoch [12/50], Loss: 0.0000
# Epoch [13/50], Loss: 0.0001
# Epoch [14/50], Loss: 0.0000
# Epoch [15/50], Loss: 0.0000
# Epoch [16/50], Loss: 0.0000
# Epoch [17/50], Loss: 0.0000
# Epoch [18/50], Loss: 0.0000
# Epoch [19/50], Loss: 0.0000
# Epoch [20/50], Loss: 0.0000
# Epoch [21/50], Loss: 0.0000
# Epoch [22/50], Loss: 0.0000
# Epoch [23/50], Loss: 0.0000
# Epoch [24/50], Loss: 0.0000
# Epoch [25/50], Loss: 0.0000
# Epoch [26/50], Loss: 0.0000
# Epoch [27/50], Loss: 0.0000
# Epoch [28/50], Loss: 0.0000
# Epoch [29/50], Loss: 0.0000
# Epoch [30/50], Loss: 0.0000
# Epoch [31/50], Loss: 0.0000
# Epoch [32/50], Loss: 0.0000
# Epoch [33/50], Loss: 0.0000
# Epoch [34/50], Loss: 0.0000
# Epoch [35/50], Loss: 0.0000
# Epoch [36/50], Loss: 0.0000
# Epoch [37/50], Loss: 0.0000
# Epoch [38/50], Loss: 0.0000
# Epoch [39/50], Loss: 0.0000
# Epoch [40/50], Loss: 0.0000
# Epoch [41/50], Loss: 0.0000
# Epoch [42/50], Loss: 0.0000
# Epoch [43/50], Loss: 0.0000
# Epoch [44/50], Loss: 0.0000
# Epoch [45/50], Loss: 0.0000
# Epoch [46/50], Loss: 0.0000
# Epoch [47/50], Loss: 0.0000
# Epoch [48/50], Loss: 0.0000
# Epoch [49/50], Loss: 0.0000
# Epoch [50/50], Loss: 0.0000
# IMF 5 Train - MSE: 0.6908, MAE: 0.5575, R²: 0.9938
# IMF 5 Test - MSE: 0.1076, MAE: 0.2498, R²: 0.9940
# Training model for IMF 6...
# Epoch [1/50], Loss: 0.0240
# Epoch [2/50], Loss: 0.0123
# Epoch [3/50], Loss: 0.0052
# Epoch [4/50], Loss: 0.0003
# Epoch [5/50], Loss: 0.0000
# Epoch [6/50], Loss: 0.0000
# Epoch [7/50], Loss: 0.0001
# Epoch [8/50], Loss: 0.0001
# Epoch [9/50], Loss: 0.0001
# Epoch [10/50], Loss: 0.0002
# Epoch [11/50], Loss: 0.0002
# Epoch [12/50], Loss: 0.0002
# Epoch [13/50], Loss: 0.0002
# Epoch [14/50], Loss: 0.0002
# Epoch [15/50], Loss: 0.0002
# Epoch [16/50], Loss: 0.0003
# Epoch [17/50], Loss: 0.0003
# Epoch [18/50], Loss: 0.0003
# Epoch [19/50], Loss: 0.0003
# Epoch [20/50], Loss: 0.0003
# Epoch [21/50], Loss: 0.0003
# Epoch [22/50], Loss: 0.0003
# Epoch [23/50], Loss: 0.0003
# Epoch [24/50], Loss: 0.0003
# Epoch [25/50], Loss: 0.0003
# Epoch [26/50], Loss: 0.0003
# Epoch [27/50], Loss: 0.0003
# Epoch [28/50], Loss: 0.0004
# Epoch [29/50], Loss: 0.0004
# Epoch [30/50], Loss: 0.0004
# Epoch [31/50], Loss: 0.0004
# Epoch [32/50], Loss: 0.0004
# Epoch [33/50], Loss: 0.0004
# Epoch [34/50], Loss: 0.0004
# Epoch [35/50], Loss: 0.0004
# Epoch [36/50], Loss: 0.0004
# Epoch [37/50], Loss: 0.0004
# Epoch [38/50], Loss: 0.0004
# Epoch [39/50], Loss: 0.0004
# Epoch [40/50], Loss: 0.0003
# Epoch [41/50], Loss: 0.0004
# Epoch [42/50], Loss: 0.0004
# Epoch [43/50], Loss: 0.0004
# Epoch [44/50], Loss: 0.0004
# Epoch [45/50], Loss: 0.0004
# Epoch [46/50], Loss: 0.0004
# Epoch [47/50], Loss: 0.0004
# Epoch [48/50], Loss: 0.0004
# Epoch [49/50], Loss: 0.0004
# Epoch [50/50], Loss: 0.0003
# IMF 6 Train - MSE: 38.7931, MAE: 4.8412, R²: 0.9403
# IMF 6 Test - MSE: 5.2737, MAE: 2.2949, R²: -31.2853
# Training model for IMF 7...
# Epoch [1/50], Loss: 0.0028
# Epoch [2/50], Loss: 0.0118
# Epoch [3/50], Loss: 0.0114
# Epoch [4/50], Loss: 0.0361
# Epoch [5/50], Loss: 0.0532
# Epoch [6/50], Loss: 0.0527
# Epoch [7/50], Loss: 0.0573
# Epoch [8/50], Loss: 0.0003
# Epoch [9/50], Loss: 0.0012
# Epoch [10/50], Loss: 0.0014
# Epoch [11/50], Loss: 0.0002
# Epoch [12/50], Loss: 0.0000
# Epoch [13/50], Loss: 0.0000
# Epoch [14/50], Loss: 0.0000
# Epoch [15/50], Loss: 0.0001
# Epoch [16/50], Loss: 0.0001
# Epoch [17/50], Loss: 0.0001
# Epoch [18/50], Loss: 0.0001
# Epoch [19/50], Loss: 0.0001
# Epoch [20/50], Loss: 0.0001
# Epoch [21/50], Loss: 0.0001
# Epoch [22/50], Loss: 0.0001
# Epoch [23/50], Loss: 0.0001
# Epoch [24/50], Loss: 0.0002
# Epoch [25/50], Loss: 0.0002
# Epoch [26/50], Loss: 0.0002
# Epoch [27/50], Loss: 0.0002
# Epoch [28/50], Loss: 0.0002
# Epoch [29/50], Loss: 0.0002
# Epoch [30/50], Loss: 0.0002
# Epoch [31/50], Loss: 0.0001
# Epoch [32/50], Loss: 0.0001
# Epoch [33/50], Loss: 0.0001
# Epoch [34/50], Loss: 0.0001
# Epoch [35/50], Loss: 0.0001
# Epoch [36/50], Loss: 0.0001
# Epoch [37/50], Loss: 0.0001
# Epoch [38/50], Loss: 0.0001
# Epoch [39/50], Loss: 0.0001
# Epoch [40/50], Loss: 0.0001
# Epoch [41/50], Loss: 0.0001
# Epoch [42/50], Loss: 0.0001
# Epoch [43/50], Loss: 0.0001
# Epoch [44/50], Loss: 0.0001
# Epoch [45/50], Loss: 0.0001
# Epoch [46/50], Loss: 0.0001
# Epoch [47/50], Loss: 0.0000
# Epoch [48/50], Loss: 0.0000
# Epoch [49/50], Loss: 0.0000
# Epoch [50/50], Loss: 0.0000
# IMF 7 Train - MSE: 422.9955, MAE: 17.4407, R²: 0.8237
# IMF 7 Test - MSE: 4.9286, MAE: 1.7816, R²: 0.7795
# Training model for IMF 8...
# Epoch [1/50], Loss: 0.0000
# Epoch [2/50], Loss: 0.0000
# Epoch [3/50], Loss: 0.0001
# Epoch [4/50], Loss: 0.0000
# Epoch [5/50], Loss: 0.0001
# Epoch [6/50], Loss: 0.0000
# Epoch [7/50], Loss: 0.0000
# Epoch [8/50], Loss: 0.0000
# Epoch [9/50], Loss: 0.0000
# Epoch [10/50], Loss: 0.0000
# Epoch [11/50], Loss: 0.0000
# Epoch [12/50], Loss: 0.0000
# Epoch [13/50], Loss: 0.0000
# Epoch [14/50], Loss: 0.0000
# Epoch [15/50], Loss: 0.0000
# Epoch [16/50], Loss: 0.0000
# Epoch [17/50], Loss: 0.0000
# Epoch [18/50], Loss: 0.0000
# Epoch [19/50], Loss: 0.0000
# Epoch [20/50], Loss: 0.0000
# Epoch [21/50], Loss: 0.0000
# Epoch [22/50], Loss: 0.0000
# Epoch [23/50], Loss: 0.0000
# Epoch [24/50], Loss: 0.0000
# Epoch [25/50], Loss: 0.0000
# Epoch [26/50], Loss: 0.0000
# Epoch [27/50], Loss: 0.0000
# Epoch [28/50], Loss: 0.0000
# Epoch [29/50], Loss: 0.0000
# Epoch [30/50], Loss: 0.0000
# Epoch [31/50], Loss: 0.0000
# Epoch [32/50], Loss: 0.0000
# Epoch [33/50], Loss: 0.0000
# Epoch [34/50], Loss: 0.0000
# Epoch [35/50], Loss: 0.0000
# Epoch [36/50], Loss: 0.0000
# Epoch [37/50], Loss: 0.0000
# Epoch [38/50], Loss: 0.0000
# Epoch [39/50], Loss: 0.0000
# Epoch [40/50], Loss: 0.0000
# Epoch [41/50], Loss: 0.0000
# Epoch [42/50], Loss: 0.0000
# Epoch [43/50], Loss: 0.0000
# Epoch [44/50], Loss: 0.0000
# Epoch [45/50], Loss: 0.0000
# Epoch [46/50], Loss: 0.0000
# Epoch [47/50], Loss: 0.0000
# Epoch [48/50], Loss: 0.0000
# Epoch [49/50], Loss: 0.0000
# Epoch [50/50], Loss: 0.0000
# IMF 8 Train - MSE: 18.5598, MAE: 3.4335, R²: 0.9306
# IMF 8 Test - MSE: 0.7746, MAE: 0.7230, R²: -1.6429
# Combined IMF Train - MSE: 354.8048, MAE: 14.6847, R²: 0.9000
# Combined IMF Test - MSE: 4.6181, MAE: 1.6969, R²: 0.9108
